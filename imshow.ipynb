# %%
import csv
from PIL import Image
from pylab import *

import numpy
my_matrix = numpy.loadtxt(open("./Bmode.csv","rb"),delimiter=",",skiprows=0) 

print(my_matrix)

imshow(my_matrix)
# Out:
# [[102. 100. 101. ... 102. 104. 104.]
#  [103. 100. 101. ... 102. 103. 101.]
#  [100. 104. 103. ... 104. 103. 102.]
#  ...
#  [102. 102. 102. ... 103. 103. 104.]
#  [102. 102. 102. ... 103. 103. 103.]
#  [101. 102. 102. ... 103. 105. 105.]]

# %%
import cv2

# %%
res = cv2.resize(my_matrix, dsize=(3118, 3118), interpolation=cv2.INTER_CUBIC)

# %%
imshow(res)
